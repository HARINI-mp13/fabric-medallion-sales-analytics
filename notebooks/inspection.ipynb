-- %%
-- Welcome to your new notebook
-- Type here in the cell editor to add code!

SELECT
    customer_id,
    COUNT(transaction_id)        AS total_orders,
    ROUND(SUM(net_revenue), 2)   AS total_revenue,
    ROUND(AVG(net_revenue), 2)   AS avg_order_value,
    ROUND(SUM(discount_amount),2)AS total_discount_given,
    SUM(quantity)                AS total_items_bought
FROM s_sales_transactions
GROUP BY customer_id
ORDER BY total_revenue DESC
-- Out:
-- StatementMeta(, 4e07e8c5-34f3-4004-a29c-37fa71ac60a6, 3, Finished, Available, Finished, False)
-- <Spark SQL result set with 100 rows and 6 fields>
